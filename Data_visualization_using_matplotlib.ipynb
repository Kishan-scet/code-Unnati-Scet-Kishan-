# %%
import matplotlib.pyplot as plt

# %%
x=[2,4,6,8,10]
y=[1,2,3,4,5]

# %%
#plot values
plt.plot(x,y)

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
x=[4,5,6,7,8]
y=[1,2,3,4,6]

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y)

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted')

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='r')

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted',color='r')

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted',color='r',marker='o')

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted',color='b',marker='+',ms=25)

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.scatter(x,y)

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#x Label
plt.xlabel("sales")
#y Label
plt.ylabel("profit")
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')
plt.bar(y,x)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Subplot

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([45,56,67,77,88,34])

plt.plot(a,b)

# %%
plt.plot(a,c)

# %%
plt.plot(a,d)

# %%
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(a,d)

#plot3
plt.subplot(2,2,3)
plt.plot(a,d)

#plot4
plt.subplot(2,2,4)
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot2
plt.subplot(2,2,3)
plt.plot(a,d)

#plot4
plt.subplot(2,2,2)
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,2)
plt.plot(a,d)

#plot3
plt.subplot(2,2,3)
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(3,2,3)
plt.plot(a,d)

#plot2
plt.subplot(3,2,2)
plt.plot(a,d)

#plot3
plt.subplot(3,2,1)
plt.plot(a,d)

#plot4
plt.subplot(3,2,4)
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d,color='r')

#plot2
plt.subplot(2,2,2)
plt.plot(a,d,color='r')

#plot3
plt.subplot(2,2,3)
plt.plot(a,d,color='r')

#plot4
plt.subplot(2,2,4)
plt.plot(a,d,color='r')

# %%
plt.plot(a,d)
#plot1
plt.subplot(3,2,3)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,2)
plt.plot(a,d,color='r')

#plot3
plt.subplot(3,2,1)
plt.plot(a,d,color='r')

#plot4
plt.subplot(3,2,4)
plt.plot(a,d,color='r')

# %%
plt.plot(a,d)
#plot1
plt.subplot(3,2,1)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,4)
plt.plot(a,d,color='r')

#plot3
plt.subplot(3,2,5)
plt.plot(a,d,color='r')

#plot4
plt.subplot(3,2,6)
plt.plot(a,d,color='r')

# %%
#Histogram
data=np.random.normal(150,10,250)

# %%
data
# Out:
# array([155.50113218, 161.5171358 , 152.44109174, 130.36158346,
#        160.35723857, 154.09453749, 145.95314093, 147.53313902,
#        158.61892792, 145.60494285, 154.84611302, 164.26198777,
#        140.8388824 , 137.64118621, 130.51993774, 158.11264785,
#        152.39575639, 152.84344996, 136.15846111, 148.24540682,
#        124.4321086 , 142.64588007, 142.51054382, 161.5062785 ,
#        152.92761428, 155.49728844, 147.86812487, 152.72447531,
#        164.18083141, 135.60629561, 157.56460038, 132.30211224,
#        139.77038528, 163.35720705, 152.64686835, 164.3220019 ,
#        141.65616941, 160.21321599, 144.31941534, 157.97346356,
#        149.06518995, 151.10101779, 133.45919108, 152.55445649,
#        157.89114746, 168.69687779, 141.4436881 , 138.92473121,
#        138.36245675, 132.6073607 , 151.58225467, 144.86554534,
#        152.88194216, 151.41643158, 155.03839102, 145.0627017 ,
#        141.15012959, 146.53785164, 159.62060669, 142.24259367,
#        143.1499273 , 142.80345806, 155.01575298, 162.0003657 ,
#        139.94146446, 144.01488559, 146.14244002, 147.22097087,
#        148.88031914, 161.16015218, 148.3111748 , 154.86688499,
#        155.16507691, 147.78238771, 164.73251369, 157.46132919,
#        145.88598372, 146.4571247 , 145.25943657, 143.13470273,
#        165.94800934, 145.7486029 , 139.41744661, 152.75069285,
#        146.72623422, 141.02317919, 151.76100493, 148.34855335,
#        151.61446518, 151.82345468, 155.00859772, 172.73269598,
#        140.63058812, 173.98189099, 161.77278969, 153.91882819,
#        151.35540547, 154.83231749, 152.49816505, 148.98541718,
#        134.28748685, 151.1730994 , 146.2839757 , 147.81462   ,
#        151.66890791, 160.0791969 , 143.74159379, 140.87737376,
#        149.15113702, 153.46113973, 148.43392184, 136.71145727,
#        158.75027529, 142.55467875, 159.39996185, 148.56333425,
#        147.08480896, 150.16349078, 154.35707694, 166.8910438 ,
#        152.83441585, 152.42624069, 154.0162729 , 143.60271237,
#        144.64950229, 146.86593967, 151.91857445, 147.97011038,
#        138.86336718, 152.02226896, 151.50250334, 152.89412168,
#        140.72752537, 146.90947018, 138.09656654, 158.04461391,
#        157.81243991, 152.79853548, 130.69590911, 147.08441351,
#        148.89515958, 138.59828739, 147.46056051, 160.45492541,
#        158.15507683, 143.18601472, 152.39284535, 146.90456327,
#        170.70345959, 164.76446401, 146.26369789, 168.78296236,
#        163.79634327, 154.16051947, 148.54037382, 139.65917405,
#        146.46924933, 140.43730021, 153.51082711, 149.49762674,
#        156.8019235 , 149.38714349, 145.0809137 , 167.70837333,
#        147.66951279, 167.70202389, 150.67619061, 156.89548373,
#        156.06293578, 152.96813098, 131.17273287, 145.11981581,
#        142.00902067, 137.30108363, 138.94927234, 158.50692973,
#        149.47741308, 152.55692946, 144.26501813, 150.93141861,
#        136.08689681, 163.83723908, 152.65819464, 164.2150839 ,
#        154.82344176, 154.90616498, 145.5088002 , 138.95458559,
#        151.22007741, 161.79236221, 157.19355311, 147.02986865,
#        136.39261814, 155.56461934, 159.79237631, 135.22100325,
#        147.03794736, 157.54314685, 161.52703733, 141.78268506,
#        131.04827938, 135.77094302, 123.46171652, 130.1937223 ,
#        139.21452363, 165.66088316, 149.2647753 , 154.94625276,
#        143.82282925, 141.32069182, 143.45426197, 148.6281692 ,
#        149.4039795 , 164.0700908 , 145.0172872 , 156.75850965,
#        147.29787375, 155.31541195, 148.56627755, 147.16456628,
#        146.88750122, 163.86328035, 152.70878318, 138.70760751,
#        153.57937115, 151.25716525, 133.53212671, 141.41014734,
#        140.77416601, 156.07989462, 156.30865768, 165.76498396,
#        159.98642133, 156.27581538, 132.5643991 , 141.90299406,
#        160.94015087, 136.57259736, 149.09613669, 143.73821263,
#        155.48085995, 162.75163893, 133.37772896, 135.79309949,
#        147.99381893, 149.30704312, 142.1910048 , 152.19948387,
#        139.49485869, 144.73923242])

# %%
len(data)
# Out:
# 250

# %%
plt.hist(data,bins=20)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6756\3523879284.py in <module>
# ----> 1 plt.hist(data1,bins=20)
#       2 plt.show
#
# NameError: name 'data1' is not defined

# %%
data=np.array([44,55,55,77,88,99])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data1)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6756\2525056057.py in <module>
# ----> 1 plt.hist(data1)
#       2 plt.show
#
# NameError: name 'data1' is not defined

# %%
#create numpy array for 18 students contaning marks of 
#and create histogram with bin size 10

# %%
import numpy as np
data=np.random.normal([44,55,66,77,88,99,56,43,56,76,89,54,40])
plt.hist(data,bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pie chart

#create dataset
cars=['audi','BMW','TATA', 'honda']
sale=[88,100,89,610]

#create pie chart
plt.pie(sale,labels=cars)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
